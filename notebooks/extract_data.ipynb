# %% [markdown]
# ### Xử lí data

# %% [markdown]
# #### 1. Xử lí data từ json

# %%
#Import thư viện cần thiết
import json
import pandas as pd
from itertools import zip_longest

# %%
rows = []

with open('../data/json/JSON1.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# Chỉ lấy id trong khoảng 849–1485
data = [item for item in data if 849 <= item.get('id', -1) <= 1485]

for item in data:
    src_id = item.get('id')
    cn_text = item.get('cn', '')
    vi_text = item.get('vi', '')
    
    cn_lines = cn_text.split('\n')
    vi_lines = vi_text.split('\n')
    
    for cn, vi in zip_longest(cn_lines, vi_lines, fillvalue=''):
        rows.append({
            'src_id': src_id,
            'src_lang': cn,
            'tgt_lang': vi
        })

df = pd.DataFrame(rows)
df.to_csv('../data/preprocessing_data/data_converted.csv', index=False, encoding='utf-8-sig')

# %%
df = pd.read_csv('../data/preprocessing_data/data_converted.csv', encoding='utf-8-sig')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41462 entries, 0 to 41461
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   src_id    41462 non-null  int64
#  1   src_lang  39561 non-null  object
#  2   tgt_lang  39244 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 971.9+ KB

# %%
df.head()
# Out:
#    src_id                                           src_lang  \
# 0     849  在使用Internet Explorer浏览器（简称为IE浏览器）浏览网站时，所有的浏览历史...
# 1     849                                                 步骤
# 2     849                                               方法 1
# 3     849                                          方法 1 的 3:
# 4     849                      使用Internet Explorer 7及7以上的浏览器
#
#                                             tgt_lang
# 0  Khi chúng ta sử dụng Internet Explorer, lịch s...
# 1                                           Các bước
# 2                                      Phương pháp 1
# 3                               Phương pháp 1 của 3:
# 4                       Sử dụng Internet Explorer 7+
