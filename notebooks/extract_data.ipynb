# %% [markdown]
# ### EXTRACT DATA

# %% [markdown]
# #### 1. Extract data from json file

# %%
# Libraries
import json
from itertools import zip_longest

# %%
def json_to_csv(json_file_path, from_id=None, to_id=None):
    """
    Read the JSON file, process the data, and save it as a CSV file.

    Parameters:
      json_file_path (str): Path to the input JSON file.
      csv_file_path (str): Path to the output CSV file.
      from_id (int, optional): Starting ID for filtering data. Defaults to None.
      to_id (int, optional): Ending ID for filtering data. Defaults to None.

    Returns:
      None
    """

    try:
        # Read JSON file
        with open(json_file_path, "r", encoding="utf-8") as json_file:
            data = json.load(json_file)

        # Normalize JSON data to list of records
        if isinstance(data, list):
            records = data
        elif isinstance(data, dict):
            records = [data]
        else:
            print("JSON data must be a list or a dictionary")
            return None

        # Filter records based on from_id and to_id
        if from_id is not None and to_id is not None:
          filtered_records = [
                  record for record in records
                  if isinstance(record, dict) and
                  from_id <= record.get('id', -1) <= to_id
          ]
          if not filtered_records:
                  print(f"No records found with ID between {from_id} and {to_id}")
                  return None
          records = filtered_records

          # Use actual min/max IDs from filtered data
          actual_ids = [record.get('id') for record in records if 'id' in record]
          if actual_ids:
              from_id = min(actual_ids)
              to_id = max(actual_ids)

        # Auto-detect from_id and to_id if not provided
        elif from_id is None and to_id is None:
            ids = [
                record.get("id")
                for record in records
                if isinstance(record, dict) and "id" in record
            ]
            if ids:
                from_id = min(ids)
                to_id = max(ids)
            else:
                from_id = 0
                to_id = len(records) - 1

        output_list = []

        for record in records:
            parent_id = record.get("id", "unknown")

            vi_text = record.get("vi", "unknown")
            cn_text = record.get("cn", "unknown")

            vi_lines = [
                line.strip()
                for line in vi_text.split("\n")
                if line.strip() and line.strip() != "-"
            ]
            cn_lines = [
                line.strip()
                for line in cn_text.split("\n")
                if line.strip() and line.strip() != "-"
            ]

            paired_lines = zip_longest(vi_lines, cn_lines, fillvalue=None)

            for index, (vi_line, cn_line) in enumerate(paired_lines, 1):
              segment_obj = {
                  "id": f"{parent_id}_{index}", # Tạo ID con: 256_1, 256_2...
                  "vi": vi_line,
                  "cn": cn_line
              }
              output_list.append(segment_obj)

        return output_list

    except FileNotFoundError:
        print(f"Error: File {json_file_path} not found")
        return None
    except json.JSONDecodeError:
        print(f"Error: Invalid JSON format in {json_file_path}")
        return None
    except Exception as e:
        print(f"Error: {str(e)}")
        return None

# %%
df = json_to_csv("./data/json/JSON1.json", from_id=1273, to_id=1484)
print(df)
# Out:
# [{'id': '1273_1', 'vi': 'Trong bài viết này, wikiHow sẽ hướng dẫn bạn cách in ảnh, tài liệu, email và nhiều nội dung khác từ iPhone. Bạn có thể in không dây nếu sử dụng máy in hỗ trợ AirPrint, hoặc dùng ứng dụng in ấn để cung cấp giao diện cho các máy in khác.', 'cn': '从iPhone中打印可以用来做很多事情，如打印照片、电子邮件和文章。本文将告诉你如何自动打印所需的消息和附件，而完成它只需轻点几下屏幕。请仔细阅读，了解如何使用特定的软件和打印机进行打印。'}, {'id': '1273_2', 'vi': 'Các bước', 'cn': '步骤'}, {'id': '1273_3', 'vi': 'Phương pháp 1', 'cn': '方法 1'}, {'id': '1273_4', 'vi': 'Phương pháp 1 của 2:', 'cn': '方法 1 的 3:'}, {'id': '1273_5', 'vi': 'In không dây', 'cn': '使用AirPrint'}, {'id': '1273_6', 'vi': '1. Chắc chắn rằng bạn có máy in hỗ trợ AirPrint. Bạn có thể kiểm tra lại mức độ tương thích của máy in để đảm bảo rằng máy có thể in không dây các nội dung từ iPhone.', 'cn': '1. 获得一个支持AirPrint的打印机。如果你有一个iPhone 3GS或更高版本的iPhone，就可以通过AirPrint 打印到支持的打印机上。近年来，主要的打印机品牌如兄弟、佳能、戴尔、惠普、利盟和三星都开始制造兼容AirPrint的打印机。'}, {'id': '1273_7', 'vi': '- Máy in và điện thoại phải kết nối cùng mạng Wi-Fi.', 'cn': '- 如果你不确定自己的打印机是否兼容AirPrint，可以查阅打印机附带的使用说明书，或致电该打印机制造商询问。'}, {'id': '1273_8', 'vi': '- Nếu không có máy in tương thích với AirPrint, bạn vẫn có thể sử dụng AirPrint bằng cách tìm mạng có máy in hỗ trợ AirPrint ở nơi làm việc, trường học, v.v.', 'cn': '- 如果你没有兼容AirPrint的打印机，你仍然可以在工作场所或其他地方找到一个具有AirPrint打印机的网络，这样你就可以通过它来进行打印了。'}, {'id': '1273_9', 'vi': '- Máy in cần được cài đặt trước khi in không dây. Vì quá trình này trên mỗi dòng máy lại khác nhau, bạn nên tham khảo hướng dẫn sử dụng để biết cách cài đặt cho máy mình đang sử dụng.', 'cn': '2. 配置打印机以使用AirPrint。有些型号的打印机自动支持AirPrint，但另一些则需要先配置。确定是否需要更改你的打印机设置，以使其能够使用AirPrint。确保你的打印机和iPhone在同一个无线网络中。'}, {'id': '1273_10', 'vi': '2. Mở ứng dụng iPhone hỗ trợ AirPrint. Hầu hết các ứng dụng của Apple đều tương thích: Mail, Safari và iPhoto. Bạn có thể in email, tài liệu và ảnh từ điện thoại.[1] Nguồn nghiên cứu', 'cn': '3. 在iPhone中打开一个支持AirPrint的应用。大多数来自苹果的应用都支持，象Mail，Safari和iPhoto。你还可以从手机中打印电子邮件、文档和图片。 [1] 研究来源'}, {'id': '1273_11', 'vi': '- Ví dụ, mở Photos (Ảnh) để in ảnh.', 'cn': '4. 打开你要打印的内容，选择“共享”，然后选择“打印”。当你选择共享时，会出现一个下拉菜单，让你选择发送短信，通过电子邮件发送，或其他。你也会看到一个“打印”选项，选择它。'}, {'id': '1273_12', 'vi': '3. Mở nội dung muốn in. Nếu muốn in ảnh hay ghi chú, bạn chỉ cần chạm vào nội dung muốn in.', 'cn': '- 如果你想打印电子邮件，点击屏幕底部的向左箭头（就像你要回复一样）。如果你是在查找一个网页，找到一个图案是盒子中的右箭头的图标。当更多选项显示出来时，点击“打印”。'}, {'id': '1273_13', 'vi': '4. Nhấn nút "Share" (Chia sẻ). Nút này có biểu tượng chiếc hộp với mũi tên chỉ xuống ở góc màn hình.', 'cn': '5. 选择打印机。当你点击“打印”，一个包含可用打印机的列表会显示出来。选择你知道的兼容AirPrint的打印机。输入要打印的页码数、份数，更改各个所需的设置然后打印。'}, {'id': '1273_14', 'vi': '- Ví dụ, nút "Share" nằm ở góc dưới cùng bên trái màn hình khi bạn mở ảnh trong Photos và nằm ở góc trên cùng bên phải màn hình nếu bạn mở ghi chú trong ứng dụng Notes (Ghi chú).', 'cn': '6. 点击“打印”。当你准备好，按下打印按钮，然后就可以看到你的文件、电子邮件或图片开始打印了。'}, {'id': '1273_15', 'vi': '- Nếu muốn in email, nhấn vào nút quay ngược lại ở cuối màn hình (ngay cạnh biểu tượng thùng rác).', 'cn': '方法 2'}, {'id': '1273_16', 'vi': '5. Nhấn vào Print (In). Nút này nằm ở hàng dưới cùng trong trình đơn "Share" hiện ra. Tùy thuộc vào nội dung muốn in mà bạn có thể phải vuốt sang bên trái để tìm tùy chọn Print.', 'cn': '方法 2 的 3:'}, {'id': '1273_17', 'vi': '- Để in email, bạn nhấn vào Print ở dưới cùng của trình đơn hiện ra.', 'cn': '通过应用打印'}, {'id': '1273_18', 'vi': '6. Nhấn vào Select Printer (Chọn Máy in) ở trên cùng màn hình. Đây là thao tác yêu cầu iPhone tìm kiếm máy in trong cùng mạng, miễn là bạn đã kết nối máy in AirPrint với Wi-Fi, tên máy in sẽ xuất hiện trong trình đơn này.', 'cn': '1. 访问iTunes应用商店，找到打印应用。你会找到一个供选择的支持从iPhone打印的应用列表。关于下载应用的更多信息可以查阅如何从iTunes 应用商店下载和使用应用。'}, {'id': '1273_19', 'vi': '- Bạn có thể nhấn nút - hoặc + dưới tùy chọn Select Printer (Chọn Máy in) để giảm hoặc tăng số bản in, hoặc bạn chạm vào từng trang của tài liệu nhiều trang để chọn hoặc bỏ chọn in trang đó.', 'cn': '- HP ePrint是一个免费的打印应用，要使用它，你需要一个网络惠普打印机或任何联网的支持手机打印的HP打印机。这个应用还可以云打印到支持HP ePrint功能的打印机，既可以从家里也可以从公共打印 ...
